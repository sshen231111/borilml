# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from tensorflow import keras
from kerastuner.tuners import RandomSearch

print(tf.config.list_physical_devices('GPU'))
# Load the MNIST dataset
df = pd.read_csv("all_freq_test_unigram.csv")
y = pd.read_csv("actual_labels_unigram.csv")
mask = pd.read_csv("squashed_unigram_mask.csv")

def plot_loss(history):
    """
    Plots the training and validation loss versus epochs.

    Args:
    - history: History object returned by model.fit(), containing training/validation loss values.

    Returns:
    - None
    """

    # Extract training and validation loss from the history object
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Create an array of epoch numbers
    epochs = range(1, len(training_loss) + 1)

    # Plot loss vs epochs
    plt.plot(epochs, training_loss, 'b', label='Training Loss')
    plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

def compute_accuracy(actual_labels, predicted_labels):
    """
    Compute the accuracy of predicted labels compared to actual labels.
    
    Args:
    actual_labels (list): List of actual labels.
    predicted_labels (list): List of predicted labels.
    
    Returns:
    float: Accuracy of the predicted labels.
    """
    # Convert lists to numpy arrays if they're not already
    actual_labels = np.array(actual_labels)
    predicted_labels = np.array(predicted_labels)
    
    # Compute accuracy
    accuracy = accuracy_score(actual_labels, predicted_labels)
    
    return accuracy

def convert_labels_to_probabilities(labels):
    """
    Convert a 1D array of binary labels into a two-column array of probabilities.
    
    Args:
    labels (numpy.ndarray): 1D array of binary labels (0 for negative, 1 for positive).
    
    Returns:
    numpy.ndarray: Two-column array of probabilities, where the first column represents the probability of being positive 
                   and the second column represents the probability of being negative.
    """
    # Initialize the probabilities array
    if isinstance(labels, pd.DataFrame):
        labels = labels.values
        
    labels = labels.reshape(-1, 1)
    probabilities = np.zeros((len(labels), 2))
    
    # Set the first column to represent the probability of being positive
    probabilities[:, 0] = 1 - labels.ravel()  # ravel() is used to convert the array to 1D
    
    # Set the second column to represent the probability of being negative
    probabilities[:, 1] = labels.ravel()
    
    return probabilities
def save_to_csv(array, file_name):
    """
    Save the given array to a CSV file.

    Parameters:
        array (list or numpy array): The array to be saved.
        file_name (str): The name of the CSV file (include .csv extension).

    Returns:
        None
    """
    # Convert the array to a pandas DataFrame
    df = pd.DataFrame(array)

    # Write the DataFrame to the CSV file
    df.to_csv(file_name, index=False)

def rotate_2x2(matrix):
    # Swap elements diagonally
    rotated_matrix = np.array([[matrix[1][1], matrix[1][0]],
                               [matrix[0][1], matrix[0][0]]])
    return rotated_matrix

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_layer1', min_value=512, max_value=1024, step=16),
                           activation='relu', input_shape=(X_train.shape[1],)))
    model.add(layers.Dropout(hp.Float('dropout_rate', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(layers.Dense(units=hp.Int('units_layer2', min_value=128, max_value=512, step=16),
                           activation='relu'))
    model.add(layers.Dropout(hp.Float('dropout_rate', min_value=0.0, max_value=0.5, step=0.1)))
    model.add(layers.Dense(units=hp.Int('units_layer2', min_value=10, max_value=128, step=16),
                           activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))

    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
df = df.transpose()
mask= mask.transpose()
# Create MinMaxScaler object
scaler_minmax = MinMaxScaler()

# Fit the scaler to your training data and transform it
mask_scaled = scaler_minmax.fit_transform(mask)
X = df.values 
# Repeat rows of BOW_pos and BOW_neg to match the number of rows in X
repeated_BOW = np.repeat(mask_scaled, X.shape[0], axis=0)
X = np.concatenate((repeated_BOW,X), axis=1)
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# Further split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

train= convert_labels_to_probabilities(y_train)
y_val= convert_labels_to_probabilities(y_val)


# Define the model
model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.5),
    layers.Dense(256, activation='relu'), 
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')
])
# Compile the model
model.compile(optimizer='adam',loss ="binary_crossentropy", metrics= ["accuracy"])

# Define your batch size
batch_size = 32
early_stopping = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True)
# Train the model on GPU
with tf.device('/GPU:0'):
     history = model.fit(X_train,train,epochs=35, batch_size= batch_size, validation_data=(X_val, y_val), callbacks=[early_stopping])  

predictions = model.predict(X_test)
save_to_csv(predictions, "NN_predictions_2.csv")
predicted_labels = [0 if ((pred[1] - pred[0]) <= 0) else 1 for pred in predictions]
save_to_csv(y_test, "NN_labels_2.csv")
acc = compute_accuracy(y_test, predicted_labels)
print(acc)
cm = confusion_matrix(y_test, predicted_labels)
cm = rotate_2x2(cm)
print(cm)
plot_loss(history)
# Out:
# Epoch 1/35
# 139/139 [==============================] - 3s 15ms/step - loss: 0.5495 - accuracy: 0.7026 - val_loss: 0.3591 - val_accuracy: 0.8402
# Epoch 2/35
# 139/139 [==============================] - 6s 45ms/step - loss: 0.3059 - accuracy: 0.8748 - val_loss: 0.3299 - val_accuracy: 0.8568
# Epoch 3/35
# 139/139 [==============================] - 2s 14ms/step - loss: 0.2208 - accuracy: 0.9211 - val_loss: 0.3354 - val_accuracy: 0.8581
# Epoch 4/35
# 139/139 [==============================] - 7s 48ms/step - loss: 0.1691 - accuracy: 0.9410 - val_loss: 0.3673 - val_accuracy: 0.8389
# Epoch 5/35
# 139/139 [==============================] - 7s 49ms/step - loss: 0.1214 - accuracy: 0.9614 - val_loss: 0.3855 - val_accuracy: 0.8593
# Epoch 6/35
# 139/139 [==============================] - 2s 14ms/step - loss: 0.0859 - accuracy: 0.9767 - val_loss: 0.4394 - val_accuracy: 0.8478
# Epoch 7/35
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0665 - accuracy: 0.9803 - val_loss: 0.4714 - val_accuracy: 0.8414
# Epoch 8/35
# 139/139 [==============================] - 2s 13ms/step - loss: 0.0437 - accuracy: 0.9898 - val_loss: 0.5561 - val_accuracy: 0.8465
# Epoch 9/35
# 139/139 [==============================] - 7s 49ms/step - loss: 0.0281 - accuracy: 0.9934 - val_loss: 0.6059 - val_accuracy: 0.8427
# Epoch 10/35
# 139/139 [==============================] - 7s 48ms/step - loss: 0.0154 - accuracy: 0.9966 - val_loss: 0.6347 - val_accuracy: 0.8389
# Epoch 11/35
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.7118 - val_accuracy: 0.8414
# Epoch 12/35
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.7037 - val_accuracy: 0.8427
# Epoch 13/35
# 139/139 [==============================] - 2s 15ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.7344 - val_accuracy: 0.8427
# Epoch 14/35
# 139/139 [==============================] - 6s 47ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.7663 - val_accuracy: 0.8376
# Epoch 15/35
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0057 - accuracy: 0.9991 - val_loss: 0.8043 - val_accuracy: 0.8389
# Epoch 16/35
# 139/139 [==============================] - 2s 14ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.8683 - val_accuracy: 0.8389
# Epoch 17/35
# 139/139 [==============================] - 7s 48ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.9070 - val_accuracy: 0.8402
# 19/19 [==============================] - 0s 4ms/step
# 0.8842832469775475
# [[294  32]
#  [ 35 218]]

# %%
df = df.transpose()
mask= mask.transpose()
# Create MinMaxScaler object
scaler_minmax = MinMaxScaler()

# Fit the scaler to your training data and transform it
BOW_scaled = scaler_minmax.fit_transform(mask)
#BOW_neg= BOW_neg.transpose()
X = df.values  # Input features (frequencies)
# Repeat rows of BOW_pos and BOW_neg to match the number of rows in X
repeated_BOW = np.repeat(BOW_scaled, X.shape[0], axis=0)

X = np.concatenate((repeated_BOW,X), axis=1)
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# Further split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, random_state=42)
train= convert_labels_to_probabilities(y_train)
y_val= convert_labels_to_probabilities(y_val)
# Initialize the RandomSearch tuner
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,  # Number of hyperparameter combinations to try
    executions_per_trial=1,
    directory='my_dir',  # Directory to save the tuning logs and checkpoints
    project_name='my_project'
)

# Perform hyperparameter tuning
tuner.search(X_train, train,
             epochs=45,
             validation_data=(X_val, y_val),
             callbacks=[keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)])

# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Best Hyperparameters: {best_hps}")

# Retrieve the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# Reloading Tuner from my_dir\my_project\tuner0.json
#
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# 976               |576               |units_layer1
# 0.4               |0.2               |dropout_rate
# 192               |176               |units_layer2
# 0.01              |0.0001            |learning_rate
#
# Epoch 1/45
#   4/131 [..............................] - ETA: 2s - loss: 0.7053 - accuracy: 0.5156  WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0076s vs `on_train_batch_end` time: 0.0113s). Check your callbacks.
# 131/131 [==============================] - 15s 93ms/step - loss: 0.4640 - accuracy: 0.7703 - val_loss: 0.3406 - val_accuracy: 0.8564
# Epoch 2/45
# 131/131 [==============================] - 5s 34ms/step - loss: 0.2757 - accuracy: 0.8988 - val_loss: 0.3781 - val_accuracy: 0.8360
# Epoch 3/45
#  27/131 [=====>........................] - ETA: 11s - loss: 0.1743 - accuracy: 0.9410
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 55
#      45 tuner = RandomSearch(
#      46     build_model,
#      47     objective='val_accuracy',
#    (...)
#      51     project_name='my_project'
#      52 )
#      54 # Perform hyperparameter tuning
# ---> 55 tuner.search(X_train, train,
#      56              epochs=45,
#      57              validation_data=(X_val, y_val),
#      58              callbacks=[keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)])
#      60 # Get the best hyperparameters
#      61 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\callbacks.py:385, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     382 if self._check_timing:
#     383     start_time = time.time()
# --> 385 logs = self._process_logs(logs, is_batch_hook=True)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\callbacks.py:292, in CallbackList._process_logs(self, logs, is_batch_hook)
#     290 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     291     return logs
# --> 292 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\kingk\anaconda3\envs\cudann\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
